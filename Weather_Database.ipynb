# %%
# Deliverable 1: Retrieve Weather Data

# 1. Import the numpy module, has the built-in random module.

import numpy as np
import pandas as pd



# 2. Create a set of random latitude and longitude comnbinations.

lats = np.random.uniform(low = -90.000, high = 90.000, size =2000)

lngs = np.random.uniform(low = -180.00, high = 180.00, size = 2000)

lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the "citypy" module.
# Use the citipy module to determine city based on latitude and longitude.

from citipy import citipy

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# 5. Perform an API call with OpenWeatherMap.

import requests

# Import the API key.
import os
from dotenv import load_dotenv
load_dotenv()
weather_api_key = os.getenv("weather_api_key")


type(weather_api_key)
# Out:
# str

# %%
# Starting URL for Weather Map API Call.

# base url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
#url = url + "&q=" + "Boston"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.

    try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            city_weather_description = city_weather["weather"][0]["description"]
            city_name = city_weather["name"]
            #print(city_name, city_weather_description)
            # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
            pass

 # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=torbay
# Processing Record 1 of Set 1 | torbay
# Torbay clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=camacupa
# Processing Record 2 of Set 1 | camacupa
# Camacupa clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cherskiy
# Processing Record 3 of Set 1 | cherskiy
# Cherskiy broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=thunder+bay
# Processing Record 4 of Set 1 | thunder bay
# Thunder Bay fog
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=qaanaaq
# Processing Record 5 of Set 1 | qaanaaq
# Qaanaaq overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bambanglipuro
# Processing Record 6 of Set 1 | bambanglipuro
# Bambanglipuro broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=boca+do+acre
# Processing Record 7 of Set 1 | boca do acre
# Boca do Acre scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=belushya+guba
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ribeira+grande
# Processing Record 9 of Set 1 | ribeira grande
# Ribeira Grande few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=waitati
# Processing Record 10 of Set 1 | waitati
# Waitati clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nouakchott
# Processing Record 11 of Set 1 | nouakchott
# Nouakchott broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=busselton
# Processing Record 12 of Set 1 | busselton
# Busselton broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=klaksvik
# Processing Record 13 of Set 1 | klaksvik
# Klaksvík overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mehamn
# Processing Record 14 of Set 1 | mehamn
# Mehamn broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bredasdorp
# Processing Record 15 of Set 1 | bredasdorp
# Bredasdorp broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sentyabrskiy
# Processing Record 16 of Set 1 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=pilao+arcado
# Processing Record 17 of Set 1 | pilao arcado
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=valparaiso
# Processing Record 18 of Set 1 | valparaiso
# Valparaíso light intensity drizzle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=laguna
# Processing Record 19 of Set 1 | laguna
# Laguna clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ternate
# Processing Record 20 of Set 1 | ternate
# Ternate scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tabou
# Processing Record 21 of Set 1 | tabou
# Tabou overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=barrow
# Processing Record 22 of Set 1 | barrow
# Barrow overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mataura
# Processing Record 23 of Set 1 | mataura
# Mataura clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cape+town
# Processing Record 24 of Set 1 | cape town
# Cape Town clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=rikitea
# Processing Record 25 of Set 1 | rikitea
# Rikitea clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=namatanai
# Processing Record 26 of Set 1 | namatanai
# Namatanai light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=price
# Processing Record 27 of Set 1 | price
# Price overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=viedma
# Processing Record 28 of Set 1 | viedma
# Viedma overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=georgetown
# Processing Record 29 of Set 1 | georgetown
# George Town few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=saldanha
# Processing Record 30 of Set 1 | saldanha
# Saldanha clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cidreira
# Processing Record 31 of Set 1 | cidreira
# Cidreira overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=barentsburg
# Processing Record 32 of Set 1 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mercedes
# Processing Record 33 of Set 1 | mercedes
# Mercedes few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=albany
# Processing Record 34 of Set 1 | albany
# Albany broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=axim
# Processing Record 35 of Set 1 | axim
# Esim scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bur+gabo
# Processing Record 36 of Set 1 | bur gabo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bengkulu
# Processing Record 37 of Set 1 | bengkulu
# Bengkulu overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=les+cayes
# Processing Record 38 of Set 1 | les cayes
# Les Cayes scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=batemans+bay
# Processing Record 39 of Set 1 | batemans bay
# Batemans Bay clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tasiilaq
# Processing Record 40 of Set 1 | tasiilaq
# Tasiilaq broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bluff
# Processing Record 41 of Set 1 | bluff
# Bluff clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=punta+arenas
# Processing Record 42 of Set 1 | punta arenas
# Punta Arenas broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=illoqqortoormiut
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nuevo+progreso
# Processing Record 44 of Set 1 | nuevo progreso
# Nuevo Progreso clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=aasiaat
# Processing Record 45 of Set 1 | aasiaat
# Aasiaat overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ampanihy
# Processing Record 46 of Set 1 | ampanihy
# Ampanihy clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hirara
# Processing Record 47 of Set 1 | hirara
# Hirara overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=port+alfred
# Processing Record 48 of Set 1 | port alfred
# Port Alfred light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=salalah
# Processing Record 49 of Set 1 | salalah
# Salalah light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kalmunai
# Processing Record 50 of Set 1 | kalmunai
# Kalmunai moderate rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=coihaique
# Processing Record 1 of Set 2 | coihaique
# Coyhaique broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=olafsvik
# Processing Record 2 of Set 2 | olafsvik
# Olafsvik broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=padang
# Processing Record 3 of Set 2 | padang
# Padang light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=port+elizabeth
# Processing Record 4 of Set 2 | port elizabeth
# Port Elizabeth few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mangrol
# Processing Record 5 of Set 2 | mangrol
# Māngrol overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bathsheba
# Processing Record 6 of Set 2 | bathsheba
# Bathsheba few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=puerto+ayora
# Processing Record 7 of Set 2 | puerto ayora
# Puerto Ayora broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=aquiraz
# Processing Record 8 of Set 2 | aquiraz
# Aquiraz broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mendi
# Processing Record 9 of Set 2 | mendi
# Mendi moderate rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tiznit
# Processing Record 10 of Set 2 | tiznit
# Tiznit Province scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=guerrero+negro
# Processing Record 11 of Set 2 | guerrero negro
# Guerrero Negro broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=shingu
# Processing Record 12 of Set 2 | shingu
# Shingū overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=dera+bugti
# Processing Record 13 of Set 2 | dera bugti
# Dera Bugti overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kodiak
# Processing Record 14 of Set 2 | kodiak
# Saint Paul Harbor moderate rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=yarim
# Processing Record 15 of Set 2 | yarim
# Yarim light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=victoria
# Processing Record 16 of Set 2 | victoria
# Hong Kong clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=new+norfolk
# Processing Record 17 of Set 2 | new norfolk
# New Norfolk broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hobart
# Processing Record 18 of Set 2 | hobart
# Hobart broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=caravelas
# Processing Record 19 of Set 2 | caravelas
# Caravelas clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ilulissat
# Processing Record 20 of Set 2 | ilulissat
# Ilulissat overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=moindou
# Processing Record 21 of Set 2 | moindou
# Moindou overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=casablanca
# Processing Record 22 of Set 2 | casablanca
# Casablanca scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=utete
# Processing Record 23 of Set 2 | utete
# Utete scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=fort+smith
# Processing Record 24 of Set 2 | fort smith
# Fort Smith clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bowen
# Processing Record 25 of Set 2 | bowen
# Bowen clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vila+velha
# Processing Record 26 of Set 2 | vila velha
# Vila Velha few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sibu
# Processing Record 27 of Set 2 | sibu
# Sibu scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=madisonville
# Processing Record 28 of Set 2 | madisonville
# Madisonville broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=taolanaro
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ushuaia
# Processing Record 30 of Set 2 | ushuaia
# Ushuaia scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=opatija
# Processing Record 31 of Set 2 | opatija
# Opatija overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=puerto+escondido
# Processing Record 32 of Set 2 | puerto escondido
# Puerto Escondido overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=atuona
# Processing Record 33 of Set 2 | atuona
# Atuona few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=upernavik
# Processing Record 34 of Set 2 | upernavik
# Upernavik overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lakes+entrance
# Processing Record 35 of Set 2 | lakes entrance
# Lakes Entrance scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ust-nera
# Processing Record 36 of Set 2 | ust-nera
# Ust-Nera overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=marcona
# Processing Record 37 of Set 2 | marcona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=aklavik
# Processing Record 38 of Set 2 | aklavik
# Aklavik overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=saint-pierre
# Processing Record 39 of Set 2 | saint-pierre
# Saint-Pierre clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hermanus
# Processing Record 40 of Set 2 | hermanus
# Hermanus overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=winneba
# Processing Record 41 of Set 2 | winneba
# Winneba broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=steamboat+springs
# Processing Record 42 of Set 2 | steamboat springs
# Steamboat Springs clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chuzhou
# Processing Record 43 of Set 2 | chuzhou
# Chuzhou clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=korla
# Processing Record 44 of Set 2 | korla
# Korla clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ambon
# Processing Record 45 of Set 2 | ambon
# Ambon City scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=haines+junction
# Processing Record 46 of Set 2 | haines junction
# Haines Junction broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=opobo
# Processing Record 47 of Set 2 | opobo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=orlik
# Processing Record 48 of Set 2 | orlik
# Orlik light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=arlit
# Processing Record 49 of Set 2 | arlit
# Arlit broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=amderma
# Processing Record 50 of Set 2 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sola
# Processing Record 1 of Set 3 | sola
# Sola few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=castro
# Processing Record 2 of Set 3 | castro
# Castro broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=grand+river+south+east
# Processing Record 3 of Set 3 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=prieska
# Processing Record 4 of Set 3 | prieska
# Prieska clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lavrentiya
# Processing Record 5 of Set 3 | lavrentiya
# Lavrentiya light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vaini
# Processing Record 6 of Set 3 | vaini
# Vaini overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=yangambi
# Processing Record 7 of Set 3 | yangambi
# Yangambi broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=butaritari
# Processing Record 8 of Set 3 | butaritari
# Butaritari light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=itoman
# Processing Record 9 of Set 3 | itoman
# Itoman few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=east+london
# Processing Record 10 of Set 3 | east london
# East London broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tuktoyaktuk
# Processing Record 11 of Set 3 | tuktoyaktuk
# Tuktoyaktuk light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=saskylakh
# Processing Record 12 of Set 3 | saskylakh
# Saskylakh few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=gravdal
# Processing Record 13 of Set 3 | gravdal
# Gravdal overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=yellowknife
# Processing Record 14 of Set 3 | yellowknife
# Yellowknife broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mbengwi
# Processing Record 15 of Set 3 | mbengwi
# Mbengwi overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=camacha
# Processing Record 16 of Set 3 | camacha
# Camacha few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mogadishu
# Processing Record 17 of Set 3 | mogadishu
# Mogadishu light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=geraldton
# Processing Record 18 of Set 3 | geraldton
# Geraldton scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kota+bahru
# Processing Record 19 of Set 3 | kota bahru
# Kota Bharu scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=moscow
# Processing Record 20 of Set 3 | moscow
# Moscow clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ancud
# Processing Record 21 of Set 3 | ancud
# Ancud light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nome
# Processing Record 22 of Set 3 | nome
# Nome overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=jamestown
# Processing Record 23 of Set 3 | jamestown
# Jamestown few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lagoa
# Processing Record 24 of Set 3 | lagoa
# Lagoa clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=dikson
# Processing Record 25 of Set 3 | dikson
# Dikson overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sorong
# Processing Record 26 of Set 3 | sorong
# Sorong broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=maputo
# Processing Record 27 of Set 3 | maputo
# Maputo scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lumeje
# Processing Record 28 of Set 3 | lumeje
# Lumeje scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kerema
# Processing Record 29 of Set 3 | kerema
# Kerema broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hambantota
# Processing Record 30 of Set 3 | hambantota
# Hambantota broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=riviere-au-renard
# Processing Record 31 of Set 3 | riviere-au-renard
# Riviere-au-Renard broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=saint+anthony
# Processing Record 32 of Set 3 | saint anthony
# Saint Anthony clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kalangala
# Processing Record 33 of Set 3 | kalangala
# Kalangala scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kavieng
# Processing Record 34 of Set 3 | kavieng
# Kavieng few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=altamira
# Processing Record 35 of Set 3 | altamira
# Altamira scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=husavik
# Processing Record 36 of Set 3 | husavik
# Husavik overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=muros
# Processing Record 37 of Set 3 | muros
# Muros clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vega+de+alatorre
# Processing Record 38 of Set 3 | vega de alatorre
# Vega de Alatorre overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sawtell
# Processing Record 39 of Set 3 | sawtell
# Sawtell scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ngukurr
# Processing Record 40 of Set 3 | ngukurr
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=oga
# Processing Record 41 of Set 3 | oga
# Oga few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=umzimvubu
# Processing Record 42 of Set 3 | umzimvubu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tsihombe
# Processing Record 43 of Set 3 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bambous+virieux
# Processing Record 44 of Set 3 | bambous virieux
# Bambous Virieux broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=saint-philippe
# Processing Record 45 of Set 3 | saint-philippe
# Saint-Philippe light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vostok
# Processing Record 46 of Set 3 | vostok
# Vostok overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=natitingou
# Processing Record 47 of Set 3 | natitingou
# Natitingou light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tuggurt
# Processing Record 48 of Set 3 | tuggurt
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=suruc
# Processing Record 49 of Set 3 | suruc
# Suruç clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=barreirinhas
# Processing Record 50 of Set 3 | barreirinhas
# Barreirinhas broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=san+cristobal
# Processing Record 1 of Set 4 | san cristobal
# San Cristobal clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=buala
# Processing Record 2 of Set 4 | buala
# Buala few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=souillac
# Processing Record 3 of Set 4 | souillac
# Souillac broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=margate
# Processing Record 4 of Set 4 | margate
# Margate broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=maine-soroa
# Processing Record 5 of Set 4 | maine-soroa
# Maïné Soroa few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hilo
# Processing Record 6 of Set 4 | hilo
# Hilo overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tura
# Processing Record 7 of Set 4 | tura
# Tura overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=khatanga
# Processing Record 8 of Set 4 | khatanga
# Khatanga scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=broome
# Processing Record 9 of Set 4 | broome
# Broome broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kulhudhuffushi
# Processing Record 10 of Set 4 | kulhudhuffushi
# Kulhudhuffushi broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=marsabit
# Processing Record 11 of Set 4 | marsabit
# Marsabit overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=harlingen
# Processing Record 12 of Set 4 | harlingen
# Harlingen broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tual
# Processing Record 13 of Set 4 | tual
# Tual overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tarata
# Processing Record 14 of Set 4 | tarata
# Tarata clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=te+anau
# Processing Record 15 of Set 4 | te anau
# Te Anau few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=arroyo
# Processing Record 16 of Set 4 | arroyo
# Arroyo de la Encomienda clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mackay
# Processing Record 17 of Set 4 | mackay
# Mackay clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=port-gentil
# Processing Record 18 of Set 4 | port-gentil
# Port-Gentil broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=severo-kurilsk
# Processing Record 19 of Set 4 | severo-kurilsk
# Severo-Kuril'sk overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=medina
# Processing Record 20 of Set 4 | medina
# Medina clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=waipawa
# Processing Record 21 of Set 4 | waipawa
# Waipawa overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hasaki
# Processing Record 22 of Set 4 | hasaki
# Hasaki broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=loralai
# Processing Record 23 of Set 4 | loralai
# Loralai overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nitra
# Processing Record 24 of Set 4 | nitra
# Nitra overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chokurdakh
# Processing Record 25 of Set 4 | chokurdakh
# Chokurdakh broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ponta+do+sol
# Processing Record 26 of Set 4 | ponta do sol
# Ponta do Sol clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hamilton
# Processing Record 27 of Set 4 | hamilton
# Hamilton scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sataua
# Processing Record 28 of Set 4 | sataua
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lyangasovo
# Processing Record 29 of Set 4 | lyangasovo
# Lyangasovo clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hovd
# Processing Record 30 of Set 4 | hovd
# Khovd scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=acurenam
# Processing Record 31 of Set 4 | acurenam
# Acurenam overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=rio+grande
# Processing Record 32 of Set 4 | rio grande
# Rio Grande overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=samusu
# Processing Record 33 of Set 4 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=jalu
# Processing Record 34 of Set 4 | jalu
# Jalu clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=puerto+parra
# Processing Record 35 of Set 4 | puerto parra
# Puerto Parra broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lompoc
# Processing Record 36 of Set 4 | lompoc
# Lompoc overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=moron
# Processing Record 37 of Set 4 | moron
# Morón broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nishihara
# Processing Record 38 of Set 4 | nishihara
# Nishihara few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chuy
# Processing Record 39 of Set 4 | chuy
# Chui overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hithadhoo
# Processing Record 40 of Set 4 | hithadhoo
# Hithadhoo overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=port+hawkesbury
# Processing Record 41 of Set 4 | port hawkesbury
# Port Hawkesbury clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=khash
# Processing Record 42 of Set 4 | khash
# Khāsh overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=waingapu
# Processing Record 43 of Set 4 | waingapu
# Waingapu few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kapaa
# Processing Record 44 of Set 4 | kapaa
# Kapaa scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nelson+bay
# Processing Record 45 of Set 4 | nelson bay
# Nelson Bay scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mar+del+plata
# Processing Record 46 of Set 4 | mar del plata
# Mar del Plata overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chlorakas
# Processing Record 47 of Set 4 | chlorakas
# Chlórakas clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=russell
# Processing Record 48 of Set 4 | russell
# Russell overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bilma
# Processing Record 49 of Set 4 | bilma
# Bilma clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hobyo
# Processing Record 50 of Set 4 | hobyo
# Hobyo broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=diego+de+almagro
# Processing Record 1 of Set 5 | diego de almagro
# Diego de Almagro clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=arman
# Processing Record 2 of Set 5 | arman
# Arman' moderate rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cockburn+town
# Processing Record 3 of Set 5 | cockburn town
# Cockburn Town few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=la+cruz
# Processing Record 4 of Set 5 | la cruz
# La Cruz broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=baykit
# Processing Record 5 of Set 5 | baykit
# Baykit overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=necochea
# Processing Record 6 of Set 5 | necochea
# Necochea overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=dukat
# Processing Record 7 of Set 5 | dukat
# Dukat clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=thinadhoo
# Processing Record 8 of Set 5 | thinadhoo
# Thinadhoo overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=paamiut
# Processing Record 9 of Set 5 | paamiut
# Paamiut clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=svetlogorsk
# Processing Record 10 of Set 5 | svetlogorsk
# Forsytheganj scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=varhaug
# Processing Record 11 of Set 5 | varhaug
# Varhaug overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=senneterre
# Processing Record 12 of Set 5 | senneterre
# Senneterre broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=humaita
# Processing Record 13 of Set 5 | humaita
# Humaitá few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=guiratinga
# Processing Record 14 of Set 5 | guiratinga
# Guiratinga scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=toliary
# Processing Record 15 of Set 5 | toliary
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=saleaula
# Processing Record 16 of Set 5 | saleaula
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vetlanda
# Processing Record 17 of Set 5 | vetlanda
# Vetlanda broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=yulara
# Processing Record 18 of Set 5 | yulara
# Yulara clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=provideniya
# Processing Record 19 of Set 5 | provideniya
# Provideniya overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=baghdad
# Processing Record 20 of Set 5 | baghdad
# Baghdad clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=carnarvon
# Processing Record 21 of Set 5 | carnarvon
# Carnarvon few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=pechora
# Processing Record 22 of Set 5 | pechora
# Pechora overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=aykhal
# Processing Record 23 of Set 5 | aykhal
# Aykhal broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=gold+coast
# Processing Record 24 of Set 5 | gold coast
# Gold Coast scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=yar-sale
# Processing Record 25 of Set 5 | yar-sale
# Yar-Sale light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=avarua
# Processing Record 26 of Set 5 | avarua
# Avarua overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lebu
# Processing Record 27 of Set 5 | lebu
# Lebu overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=trinidad
# Processing Record 28 of Set 5 | trinidad
# La Santisima Trinidad clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=riaba
# Processing Record 29 of Set 5 | riaba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=urucara
# Processing Record 30 of Set 5 | urucara
# Urucará overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=traralgon
# Processing Record 31 of Set 5 | traralgon
# Traralgon broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=codrington
# Processing Record 32 of Set 5 | codrington
# Codrington scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=norman+wells
# Processing Record 33 of Set 5 | norman wells
# Norman Wells broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=los+llanos+de+aridane
# Processing Record 34 of Set 5 | los llanos de aridane
# Los Llanos de Aridane overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=harper
# Processing Record 35 of Set 5 | harper
# Harper overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=havre
# Processing Record 36 of Set 5 | havre
# Arrondissement du Havre clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=taksimo
# Processing Record 37 of Set 5 | taksimo
# Taksimo light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=praia
# Processing Record 38 of Set 5 | praia
# Praia broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=adre
# Processing Record 39 of Set 5 | adre
# Adré overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=port+hardy
# Processing Record 40 of Set 5 | port hardy
# Port Hardy scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=komsomolskiy
# Processing Record 41 of Set 5 | komsomolskiy
# Yangi Marg`ilon few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=magaria
# Processing Record 42 of Set 5 | magaria
# Magaria broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=defiance
# Processing Record 43 of Set 5 | defiance
# Defiance broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nikolskoye
# Processing Record 44 of Set 5 | nikolskoye
# Nikolskoye overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=poya
# Processing Record 45 of Set 5 | poya
# Poya broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mastic+beach
# Processing Record 46 of Set 5 | mastic beach
# Mastic Beach scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=biak
# Processing Record 47 of Set 5 | biak
# Biak broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sao+filipe
# Processing Record 48 of Set 5 | sao filipe
# São Filipe light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=genhe
# Processing Record 49 of Set 5 | genhe
# Genhe broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=khonuu
# Processing Record 50 of Set 5 | khonuu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=woodward
# Processing Record 1 of Set 6 | woodward
# Woodward clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mundo+nuevo
# Processing Record 2 of Set 6 | mundo nuevo
# Mundo Nuevo (Ojo de Agua) light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=narsaq
# Processing Record 3 of Set 6 | narsaq
# Narsaq overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=xai-xai
# Processing Record 4 of Set 6 | xai-xai
# Xai-Xai clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=trairi
# Processing Record 5 of Set 6 | trairi
# Trairi few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nanga+eboko
# Processing Record 6 of Set 6 | nanga eboko
# Nanga Eboko overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=porrentruy
# Processing Record 7 of Set 6 | porrentruy
# Porrentruy scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mana
# Processing Record 8 of Set 6 | mana
# Mana overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=rundu
# Processing Record 9 of Set 6 | rundu
# Rundu clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kloulklubed
# Processing Record 10 of Set 6 | kloulklubed
# Kloulklubed heavy intensity rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=thompson
# Processing Record 11 of Set 6 | thompson
# Thompson overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=dallas
# Processing Record 12 of Set 6 | dallas
# Dallas clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=pevek
# Processing Record 13 of Set 6 | pevek
# Pevek overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=krasnoselkup
# Processing Record 14 of Set 6 | krasnoselkup
# Krasnosel'kup light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=udachnyy
# Processing Record 15 of Set 6 | udachnyy
# Udachny broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=katsuura
# Processing Record 16 of Set 6 | katsuura
# Katsuura overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=arraial+do+cabo
# Processing Record 17 of Set 6 | arraial do cabo
# Arraial do Cabo few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=pinos
# Processing Record 18 of Set 6 | pinos
# Pinos clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=pochutla
# Processing Record 19 of Set 6 | pochutla
# Pochutla overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=port+macquarie
# Processing Record 20 of Set 6 | port macquarie
# Port Macquarie broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mpika
# Processing Record 21 of Set 6 | mpika
# Mpika few clouds
# ...
# Processing Record 5 of Set 14 | tutoia
# Tutóia broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=warqla
# Processing Record 6 of Set 14 | warqla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sofiysk
# Processing Record 7 of Set 14 | sofiysk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=louisbourg
# Processing Record 8 of Set 14 | louisbourg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bosaso
# Processing Record 9 of Set 14 | bosaso
# Bosaso broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=wahiawa
# Processing Record 10 of Set 14 | wahiawa
# Wahiawā clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=przeworsk
# Processing Record 11 of Set 14 | przeworsk
# Przeworsk overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tarko-sale
# Processing Record 12 of Set 14 | tarko-sale
# Tarko-Sale overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=antofagasta
# Processing Record 13 of Set 14 | antofagasta
# Antofagasta clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=agadez
# Processing Record 14 of Set 14 | agadez
# Agadez broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=riachao
# Processing Record 15 of Set 14 | riachao
# Riachão scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kohtla-jarve
# Processing Record 16 of Set 14 | kohtla-jarve
# Kohtla-Järve overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=savelugu
# Processing Record 17 of Set 14 | savelugu
# Savelugu overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=langarud
# Processing Record 18 of Set 14 | langarud
# Langarūd light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bambey
# Processing Record 19 of Set 14 | bambey
# Bambey moderate rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sembe
# Processing Record 20 of Set 14 | sembe
# Sémbé broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=zyryanka
# Processing Record 21 of Set 14 | zyryanka
# Zyryanka clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mitu
# Processing Record 22 of Set 14 | mitu
# Mitú overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=seoul
# Processing Record 23 of Set 14 | seoul
# Seoul overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=basco
# Processing Record 24 of Set 14 | basco
# Basco overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=aberdeen
# Processing Record 25 of Set 14 | aberdeen
# Aberdeen few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=asuncion
# Processing Record 26 of Set 14 | asuncion
# Asunción clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chumikan
# Processing Record 27 of Set 14 | chumikan
# Chumikan scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=giddalur
# Processing Record 28 of Set 14 | giddalur
# Giddalūr overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kayes
# Processing Record 29 of Set 14 | kayes
# Kayes overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mentok
# Processing Record 30 of Set 14 | mentok
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=capoterra
# Processing Record 31 of Set 14 | capoterra
# Capoterra clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=moerai
# Processing Record 32 of Set 14 | moerai
# Moerai overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=havoysund
# Processing Record 33 of Set 14 | havoysund
# Havøysund overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=boden
# Processing Record 34 of Set 14 | boden
# Boden overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ashtabula
# Processing Record 35 of Set 14 | ashtabula
# Ashtabula clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mokhsogollokh
# Processing Record 36 of Set 14 | mokhsogollokh
# Mokhsogollokh clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=yarmouth
# Processing Record 37 of Set 14 | yarmouth
# Yarmouth clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nikel
# Processing Record 38 of Set 14 | nikel
# Nikel broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nouadhibou
# Processing Record 39 of Set 14 | nouadhibou
# Nouadhibou moderate rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=aswan
# Processing Record 40 of Set 14 | aswan
# Aswān broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nemuro
# Processing Record 41 of Set 14 | nemuro
# Nemuro light rain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mandalgovi
# Processing Record 42 of Set 14 | mandalgovi
# Mandalgovi scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=port+blair
# Processing Record 43 of Set 14 | port blair
# Port Blair broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kattivakkam
# Processing Record 44 of Set 14 | kattivakkam
# Kattivākkam overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=gillette
# Processing Record 45 of Set 14 | gillette
# Gillette clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=novyy+karachay
# Processing Record 46 of Set 14 | novyy karachay
# Novyy Karachay broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=andros+town
# Processing Record 47 of Set 14 | andros town
# Andros Town clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=finschhafen
# Processing Record 48 of Set 14 | finschhafen
# Finschhafen scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=evanston
# Processing Record 49 of Set 14 | evanston
# Evanston scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kudligi
# Processing Record 50 of Set 14 | kudligi
# Kūdligi broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=babynino
# Processing Record 1 of Set 15 | babynino
# Babynino clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=garowe
# Processing Record 2 of Set 15 | garowe
# Garoowe broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=contamana
# Processing Record 3 of Set 15 | contamana
# Contamana broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=oum+hadjer
# Processing Record 4 of Set 15 | oum hadjer
# Umm Hājar scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=solnechnyy
# Processing Record 5 of Set 15 | solnechnyy
# Solnechnyy overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=imelda
# Processing Record 6 of Set 15 | imelda
# Imelda overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sumenep
# Processing Record 7 of Set 15 | sumenep
# Sumenep few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sorland
# Processing Record 8 of Set 15 | sorland
# Sørland overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=conceicao+do+araguaia
# Processing Record 9 of Set 15 | conceicao do araguaia
# Conceição do Araguaia scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chifeng
# Processing Record 10 of Set 15 | chifeng
# Chifeng clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chardara
# Processing Record 11 of Set 15 | chardara
# Chardara clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nanakuli
# Processing Record 12 of Set 15 | nanakuli
# Nānākuli clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=filadelfia
# Processing Record 13 of Set 15 | filadelfia
# Philadelphia few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=katangli
# Processing Record 14 of Set 15 | katangli
# Katangli broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=alta+floresta
# Processing Record 15 of Set 15 | alta floresta
# Alta Floresta few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ballina
# Processing Record 16 of Set 15 | ballina
# Ballina scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=come
# Processing Record 17 of Set 15 | come
# Comé overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bonfim
# Processing Record 18 of Set 15 | bonfim
# Bonfim overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=flin+flon
# Processing Record 19 of Set 15 | flin flon
# Flin Flon overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ottawa
# Processing Record 20 of Set 15 | ottawa
# Ottawa scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=agva
# Processing Record 21 of Set 15 | agva
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=graz
# Processing Record 22 of Set 15 | graz
# Graz overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=binga
# Processing Record 23 of Set 15 | binga
# Binga clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=rorvik
# Processing Record 24 of Set 15 | rorvik
# Rørvik overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kirovskiy
# Processing Record 25 of Set 15 | kirovskiy
# Kirovskiy overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=trofors
# Processing Record 26 of Set 15 | trofors
# Trofors overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=valdivia
# Processing Record 27 of Set 15 | valdivia
# Valdivia overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tyachiv
# Processing Record 28 of Set 15 | tyachiv
# Tyachiv broken clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=la+ronge
# Processing Record 29 of Set 15 | la ronge
# La Ronge scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=santa+maria
# Processing Record 30 of Set 15 | santa maria
# Santa Maria overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=znamenskoye
# Processing Record 31 of Set 15 | znamenskoye
# Znamenskoye overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=masallatah
# Processing Record 32 of Set 15 | masallatah
# Masallātah clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=enshi
# Processing Record 33 of Set 15 | enshi
# Enshi scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=pandelys
# Processing Record 34 of Set 15 | pandelys
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=oktyabrskiy
# Processing Record 35 of Set 15 | oktyabrskiy
# Oktyabr'skiy overcast clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=papa
# Processing Record 36 of Set 15 | papa
# Pápa clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kishapu
# Processing Record 37 of Set 15 | kishapu
# Kishapu scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=evensk
# Processing Record 38 of Set 15 | evensk
# Evensk clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=zaritap
# Processing Record 39 of Set 15 | zaritap
# Zaritap clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mound
# Processing Record 40 of Set 15 | mound
# Mound scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=goundam
# Processing Record 41 of Set 15 | goundam
# Goundam scattered clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ust-kuyga
# Processing Record 42 of Set 15 | ust-kuyga
# Ust-Kuyga few clouds
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=beni+suef
# Processing Record 43 of Set 15 | beni suef
# Beni Suef clear sky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=oistins
# Processing Record 44 of Set 15 | oistins
# Oistins few clouds
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.

city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Torbay  47.6666  -52.7314     61.92        91           5       16.22
# 1     Camacupa -12.0167   17.4833     54.55        51           4        3.78
# 2     Cherskiy  68.7500  161.3000     62.71        40          63       10.40
# 3  Thunder Bay  48.4001  -89.3168     60.78       100         100        2.30
# 4      Qaanaaq  77.4840  -69.3632     37.36        99         100        0.65
#
#   Country Current Description
# 0      CA           clear sky
# 1      AO           clear sky
# 2      RU       broken clouds
# 3      CA                 fog
# 4      GL     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity","Cloudiness", "Wind Speed", "Current Description"]
city_data_df= city_data_df[new_column_order ]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Torbay      CA  47.6666  -52.7314     61.92        91           5
# 1        Camacupa      AO -12.0167   17.4833     54.55        51           4
# 2        Cherskiy      RU  68.7500  161.3000     62.71        40          63
# 3     Thunder Bay      CA  48.4001  -89.3168     60.78       100         100
# 4         Qaanaaq      GL  77.4840  -69.3632     37.36        99         100
# 5   Bambanglipuro      ID  -7.9500  110.2833     79.95        69          81
# 6    Boca Do Acre      BR  -8.7522  -67.3978     74.41        83          49
# 7  Ribeira Grande      PT  38.5167  -28.7000     73.31        89          14
# 8         Waitati      NZ -45.7500  170.5667     45.81        74           1
# 9      Nouakchott      MR  18.0858  -15.9785     76.98        89          77
#
#    Wind Speed Current Description
# 0       16.22           clear sky
# 1        3.78           clear sky
# 2       10.40       broken clouds
# 3        2.30                 fog
# 4        0.65     overcast clouds
# 5       16.20       broken clouds
# 6        2.55    scattered clouds
# 7        6.13          few clouds
# 8        5.37           clear sky
# 9        9.93       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
