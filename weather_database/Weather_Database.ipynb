# %%
# Deliverable 1: Retrieve Weather Data

# 1. Import the numpy module, has the built-in random module.

import numpy as np
import pandas as pd



# 2. Create a set of random latitude and longitude comnbinations.

lats = np.random.uniform(low = -90.000, high = 90.000, size =2000)

lngs = np.random.uniform(low = -180.00, high = 180.00, size = 2000)

lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the "citypy" module.
# Use the citipy module to determine city based on latitude and longitude.

from citipy import citipy

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# 5. Perform an API call with OpenWeatherMap.

import requests

# Import the API key.
import os
from dotenv import load_dotenv
load_dotenv()
weather_api_key = os.getenv("weather_api_key")


type(weather_api_key)
# Out:
# str

# %%
# Starting URL for Weather Map API Call.

# base url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.

    try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            city_weather_description = city_weather["weather"][0]["description"]
            city_name = city_weather["name"]
            #print(city_name, city_weather_description)
            # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Current Weather": city_weather_description})

    # If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
            pass

 # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tasiilaq
# Processing Record 1 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vila+franca+do+campo
# Processing Record 2 of Set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nizhneyansk
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=belmonte
# Processing Record 4 of Set 1 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nogliki
# Processing Record 5 of Set 1 | nogliki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mataura
# Processing Record 6 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hithadhoo
# Processing Record 7 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sisimiut
# Processing Record 8 of Set 1 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bredasdorp
# Processing Record 9 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lata
# Processing Record 10 of Set 1 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=oranjemund
# Processing Record 11 of Set 1 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hermanus
# Processing Record 12 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=emerald
# Processing Record 13 of Set 1 | emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kavieng
# Processing Record 14 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=huamachuco
# Processing Record 15 of Set 1 | huamachuco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=buin
# Processing Record 16 of Set 1 | buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=taolanaro
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=jamestown
# Processing Record 18 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tiksi
# Processing Record 19 of Set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ostrovnoy
# Processing Record 20 of Set 1 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=dingle
# Processing Record 21 of Set 1 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=puerto+ayora
# Processing Record 22 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=new+norfolk
# Processing Record 23 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=rovaniemi
# Processing Record 24 of Set 1 | rovaniemi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kumbo
# Processing Record 25 of Set 1 | kumbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=georgetown
# Processing Record 26 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lagoa
# Processing Record 27 of Set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bada
# Processing Record 28 of Set 1 | bada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mahebourg
# Processing Record 29 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=corowa
# Processing Record 30 of Set 1 | corowa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=homer
# Processing Record 31 of Set 1 | homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chicama
# Processing Record 32 of Set 1 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=saskylakh
# Processing Record 33 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sitka
# Processing Record 34 of Set 1 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kudahuvadhoo
# Processing Record 35 of Set 1 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=coquimbo
# Processing Record 36 of Set 1 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hobart
# Processing Record 37 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=punta+arenas
# Processing Record 38 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=rikitea
# Processing Record 39 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=iqaluit
# Processing Record 40 of Set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=charters+towers
# Processing Record 41 of Set 1 | charters towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=salalah
# Processing Record 42 of Set 1 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=avarua
# Processing Record 43 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=padang
# Processing Record 44 of Set 1 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=port+alfred
# Processing Record 45 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=princeton
# Processing Record 46 of Set 1 | princeton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cidreira
# Processing Record 47 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ponta+do+sol
# Processing Record 48 of Set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=faanui
# Processing Record 49 of Set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=comodoro+rivadavia
# Processing Record 50 of Set 1 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ambon
# Processing Record 1 of Set 2 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=albany
# Processing Record 2 of Set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hasaki
# Processing Record 3 of Set 2 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=henties+bay
# Processing Record 4 of Set 2 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nanortalik
# Processing Record 5 of Set 2 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=alakurtti
# Processing Record 6 of Set 2 | alakurtti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vaini
# Processing Record 7 of Set 2 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=muros
# Processing Record 8 of Set 2 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=aklavik
# Processing Record 9 of Set 2 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tuktoyaktuk
# Processing Record 10 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=barentsburg
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=khatanga
# Processing Record 12 of Set 2 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=abu+samrah
# Processing Record 13 of Set 2 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=grand+river+south+east
# Processing Record 14 of Set 2 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=busselton
# Processing Record 15 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cheuskiny
# Processing Record 16 of Set 2 | cheuskiny
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tabou
# Processing Record 17 of Set 2 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hilo
# Processing Record 18 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kodiak
# Processing Record 19 of Set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=fukue
# Processing Record 20 of Set 2 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lebu
# Processing Record 21 of Set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cherskiy
# Processing Record 22 of Set 2 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=puerto+narino
# Processing Record 23 of Set 2 | puerto narino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=barcelona
# Processing Record 24 of Set 2 | barcelona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=san+cristobal
# Processing Record 25 of Set 2 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=louisbourg
# Processing Record 26 of Set 2 | louisbourg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=huarmey
# Processing Record 27 of Set 2 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=luderitz
# Processing Record 28 of Set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=saldanha
# Processing Record 29 of Set 2 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ushuaia
# Processing Record 30 of Set 2 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cabo+san+lucas
# Processing Record 31 of Set 2 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chivilcoy
# Processing Record 32 of Set 2 | chivilcoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=gamba
# Processing Record 33 of Set 2 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bethel
# Processing Record 34 of Set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bathsheba
# Processing Record 35 of Set 2 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cape+town
# Processing Record 36 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=aflu
# Processing Record 37 of Set 2 | aflu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=galveston
# Processing Record 38 of Set 2 | galveston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=samusu
# Processing Record 39 of Set 2 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=illoqqortoormiut
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=guerrero+negro
# Processing Record 41 of Set 2 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=terme
# Processing Record 42 of Set 2 | terme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=puqi
# Processing Record 43 of Set 2 | puqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=clarence+town
# Processing Record 44 of Set 2 | clarence town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=krasnyy+chikoy
# Processing Record 45 of Set 2 | krasnyy chikoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=yellowknife
# Processing Record 46 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=rocha
# Processing Record 47 of Set 2 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=minbu
# Processing Record 48 of Set 2 | minbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kamina
# Processing Record 49 of Set 2 | kamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=holland
# Processing Record 50 of Set 2 | holland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nyakahanga
# Processing Record 1 of Set 3 | nyakahanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bluff
# Processing Record 2 of Set 3 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=souillac
# Processing Record 3 of Set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=treinta+y+tres
# Processing Record 4 of Set 3 | treinta y tres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=qaanaaq
# Processing Record 5 of Set 3 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chokurdakh
# Processing Record 6 of Set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=aksarka
# Processing Record 7 of Set 3 | aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=green+valley
# Processing Record 8 of Set 3 | green valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=walvis+bay
# Processing Record 9 of Set 3 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=arraial+do+cabo
# Processing Record 10 of Set 3 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mahanoro
# Processing Record 11 of Set 3 | mahanoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=esperance
# Processing Record 12 of Set 3 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=upernavik
# Processing Record 13 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bud
# Processing Record 14 of Set 3 | bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=barrow
# Processing Record 15 of Set 3 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ilulissat
# Processing Record 16 of Set 3 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mayo
# Processing Record 17 of Set 3 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=pirot
# Processing Record 18 of Set 3 | pirot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=arlit
# Processing Record 19 of Set 3 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=plettenberg+bay
# Processing Record 20 of Set 3 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=keti+bandar
# Processing Record 21 of Set 3 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kalininsk
# Processing Record 22 of Set 3 | kalininsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kibala
# Processing Record 23 of Set 3 | kibala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=castro
# Processing Record 24 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=conceicao+do+araguaia
# Processing Record 25 of Set 3 | conceicao do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=arman
# Processing Record 26 of Set 3 | arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=onega
# Processing Record 27 of Set 3 | onega
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=klaksvik
# Processing Record 28 of Set 3 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=richards+bay
# Processing Record 29 of Set 3 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=siuna
# Processing Record 30 of Set 3 | siuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=namatanai
# Processing Record 31 of Set 3 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=attawapiskat
# Processing Record 32 of Set 3 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=makakilo+city
# Processing Record 33 of Set 3 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=atuona
# Processing Record 34 of Set 3 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=banovici
# Processing Record 35 of Set 3 | banovici
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=beyneu
# Processing Record 36 of Set 3 | beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=puerto+leguizamo
# Processing Record 37 of Set 3 | puerto leguizamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=provideniya
# Processing Record 38 of Set 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=maniitsoq
# Processing Record 39 of Set 3 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=naze
# Processing Record 40 of Set 3 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=denpasar
# Processing Record 41 of Set 3 | denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sorkjosen
# Processing Record 42 of Set 3 | sorkjosen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=wajid
# Processing Record 43 of Set 3 | wajid
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mar+del+plata
# Processing Record 44 of Set 3 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=saint-philippe
# Processing Record 45 of Set 3 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=santa+catarina+de+tepehuanes
# Processing Record 46 of Set 3 | santa catarina de tepehuanes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=carnarvon
# Processing Record 47 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=belushya+guba
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cochrane
# Processing Record 49 of Set 3 | cochrane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=adamovka
# Processing Record 50 of Set 3 | adamovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bom+jesus
# Processing Record 1 of Set 4 | bom jesus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chengde
# Processing Record 2 of Set 4 | chengde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=marostica
# Processing Record 3 of Set 4 | marostica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chumikan
# Processing Record 4 of Set 4 | chumikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=clyde+river
# Processing Record 5 of Set 4 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=severo-kurilsk
# Processing Record 6 of Set 4 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chuy
# Processing Record 7 of Set 4 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=meulaboh
# Processing Record 8 of Set 4 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=olafsvik
# Processing Record 9 of Set 4 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=grootfontein
# Processing Record 10 of Set 4 | grootfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=seoul
# Processing Record 11 of Set 4 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lavrentiya
# Processing Record 12 of Set 4 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bambous+virieux
# Processing Record 13 of Set 4 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=liverpool
# Processing Record 14 of Set 4 | liverpool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=luanda
# Processing Record 15 of Set 4 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=amahai
# Processing Record 16 of Set 4 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vodnyy
# Processing Record 17 of Set 4 | vodnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=gondanglegi
# Processing Record 18 of Set 4 | gondanglegi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=marsaxlokk
# Processing Record 19 of Set 4 | marsaxlokk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ribeira+grande
# Processing Record 20 of Set 4 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=samfya
# Processing Record 21 of Set 4 | samfya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=santa+maria
# Processing Record 22 of Set 4 | santa maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=la+ciotat
# Processing Record 23 of Set 4 | la ciotat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=paamiut
# Processing Record 24 of Set 4 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=east+london
# Processing Record 25 of Set 4 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bouna
# Processing Record 26 of Set 4 | bouna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=west+odessa
# Processing Record 27 of Set 4 | west odessa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=torrington
# Processing Record 28 of Set 4 | torrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=gat
# Processing Record 29 of Set 4 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=singapore
# Processing Record 30 of Set 4 | singapore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kruisfontein
# Processing Record 31 of Set 4 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sangar
# Processing Record 32 of Set 4 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=barra+da+estiva
# Processing Record 33 of Set 4 | barra da estiva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=andra
# Processing Record 34 of Set 4 | andra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=paragominas
# Processing Record 35 of Set 4 | paragominas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=palana
# Processing Record 36 of Set 4 | palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=stornoway
# Processing Record 37 of Set 4 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=fort+nelson
# Processing Record 38 of Set 4 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=saint+george
# Processing Record 39 of Set 4 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nikolskoye
# Processing Record 40 of Set 4 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=abu+dhabi
# Processing Record 41 of Set 4 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=luchow
# Processing Record 42 of Set 4 | luchow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=san+carlos+de+bariloche
# Processing Record 43 of Set 4 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=gerede
# Processing Record 44 of Set 4 | gerede
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=seydi
# Processing Record 45 of Set 4 | seydi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=katsuura
# Processing Record 46 of Set 4 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ihosy
# Processing Record 47 of Set 4 | ihosy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=butaritari
# Processing Record 48 of Set 4 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=pacific+grove
# Processing Record 49 of Set 4 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=yakima
# Processing Record 50 of Set 4 | yakima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kapaa
# Processing Record 1 of Set 5 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=banepa
# Processing Record 2 of Set 5 | banepa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mago
# Processing Record 3 of Set 5 | mago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kutina
# Processing Record 4 of Set 5 | kutina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=saint+andrews
# Processing Record 5 of Set 5 | saint andrews
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bengkulu
# Processing Record 6 of Set 5 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=jalu
# Processing Record 7 of Set 5 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=naron
# Processing Record 8 of Set 5 | naron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=udachnyy
# Processing Record 9 of Set 5 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=asfi
# Processing Record 10 of Set 5 | asfi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cayenne
# Processing Record 11 of Set 5 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cherkasskoye
# Processing Record 12 of Set 5 | cherkasskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=urumqi
# Processing Record 13 of Set 5 | urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=rio+grande
# Processing Record 14 of Set 5 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lasa
# Processing Record 15 of Set 5 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=poum
# Processing Record 16 of Set 5 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=meyungs
# Processing Record 17 of Set 5 | meyungs
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mys+shmidta
# Processing Record 18 of Set 5 | mys shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=raga
# Processing Record 19 of Set 5 | raga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=excelsior+springs
# Processing Record 20 of Set 5 | excelsior springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kenai
# Processing Record 21 of Set 5 | kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=karamay
# Processing Record 22 of Set 5 | karamay
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nalut
# Processing Record 23 of Set 5 | nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=oksfjord
# Processing Record 24 of Set 5 | oksfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=edson
# Processing Record 25 of Set 5 | edson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=norman+wells
# Processing Record 26 of Set 5 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=broome
# Processing Record 27 of Set 5 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=asyut
# Processing Record 28 of Set 5 | asyut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=san+vicente
# Processing Record 29 of Set 5 | san vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=samalaeulu
# Processing Record 30 of Set 5 | samalaeulu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ahipara
# Processing Record 31 of Set 5 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ulaangom
# Processing Record 32 of Set 5 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=batasan
# Processing Record 33 of Set 5 | batasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=riyadh
# Processing Record 34 of Set 5 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=cloquet
# Processing Record 35 of Set 5 | cloquet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=encheng
# Processing Record 36 of Set 5 | encheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=voi
# Processing Record 37 of Set 5 | voi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ixtapa
# Processing Record 38 of Set 5 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=san+rafael
# Processing Record 39 of Set 5 | san rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=svit
# Processing Record 40 of Set 5 | svit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tel+aviv-yafo
# Processing Record 41 of Set 5 | tel aviv-yafo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bilma
# Processing Record 42 of Set 5 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tenjo
# Processing Record 43 of Set 5 | tenjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=constitucion
# Processing Record 44 of Set 5 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ancud
# Processing Record 45 of Set 5 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=matara
# Processing Record 46 of Set 5 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hobyo
# Processing Record 47 of Set 5 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vanimo
# Processing Record 48 of Set 5 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=panaba
# Processing Record 49 of Set 5 | panaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=maceio
# Processing Record 50 of Set 5 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=buariki
# Processing Record 1 of Set 6 | buariki
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=marcona
# Processing Record 2 of Set 6 | marcona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bridlington
# Processing Record 3 of Set 6 | bridlington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sao+filipe
# Processing Record 4 of Set 6 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ca+mau
# Processing Record 5 of Set 6 | ca mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=port+elizabeth
# Processing Record 6 of Set 6 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=rezina
# Processing Record 7 of Set 6 | rezina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=saint-louis
# Processing Record 8 of Set 6 | saint-louis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=qasigiannguit
# Processing Record 9 of Set 6 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vostok
# Processing Record 10 of Set 6 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=otradnoye
# Processing Record 11 of Set 6 | otradnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tiebissou
# Processing Record 12 of Set 6 | tiebissou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=pevek
# Processing Record 13 of Set 6 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lompoc
# Processing Record 14 of Set 6 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ulaanbaatar
# Processing Record 15 of Set 6 | ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=uni
# Processing Record 16 of Set 6 | uni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=puerto+carreno
# Processing Record 17 of Set 6 | puerto carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=port+shepstone
# Processing Record 18 of Set 6 | port shepstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kununurra
# Processing Record 19 of Set 6 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kattivakkam
# Processing Record 20 of Set 6 | kattivakkam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=verkhnevilyuysk
# Processing Record 21 of Set 6 | verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tarko-sale
# Processing Record 22 of Set 6 | tarko-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kamenskoye
# Processing Record 23 of Set 6 | kamenskoye
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=dukat
# Processing Record 24 of Set 6 | dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=okhotsk
# Processing Record 25 of Set 6 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=praia
# Processing Record 26 of Set 6 | praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kristiansund
# Processing Record 27 of Set 6 | kristiansund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=thompson
# Processing Record 28 of Set 6 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=takab
# Processing Record 29 of Set 6 | takab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=touros
# Processing Record 30 of Set 6 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=puerto+quijarro
# Processing Record 31 of Set 6 | puerto quijarro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chegdomyn
# Processing Record 32 of Set 6 | chegdomyn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sentyabrskiy
# Processing Record 33 of Set 6 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=dikson
# Processing Record 34 of Set 6 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=umm+lajj
# Processing Record 35 of Set 6 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ayna
# Processing Record 36 of Set 6 | ayna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=karratha
# Processing Record 37 of Set 6 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=pizarro
# Processing Record 38 of Set 6 | pizarro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vila+velha
# Processing Record 39 of Set 6 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=geraldton
# Processing Record 40 of Set 6 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vaitupu
# Processing Record 41 of Set 6 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=carballo
# Processing Record 42 of Set 6 | carballo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=college
# Processing Record 43 of Set 6 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=la+paz
# Processing Record 44 of Set 6 | la paz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=katol
# Processing Record 45 of Set 6 | katol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=gimli
# Processing Record 46 of Set 6 | gimli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=inirida
# Processing Record 47 of Set 6 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=deputatskiy
# Processing Record 48 of Set 6 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=srednekolymsk
# Processing Record 49 of Set 6 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=pringsewu
# Processing Record 50 of Set 6 | pringsewu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=strezhevoy
# Processing Record 1 of Set 7 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=riohacha
# Processing Record 2 of Set 7 | riohacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=biograd+na+moru
# Processing Record 3 of Set 7 | biograd na moru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nouadhibou
# Processing Record 4 of Set 7 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=pontal+do+parana
# Processing Record 5 of Set 7 | pontal do parana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=priyutnoye
# Processing Record 6 of Set 7 | priyutnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=buala
# Processing Record 7 of Set 7 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=seminole
# Processing Record 8 of Set 7 | seminole
# ...
# Processing Record 42 of Set 13 | puerto gaitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bolshiye+chapurniki
# Processing Record 43 of Set 13 | bolshiye chapurniki
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bandiagara
# Processing Record 44 of Set 13 | bandiagara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=espanola
# Processing Record 45 of Set 13 | espanola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=xacmaz
# Processing Record 46 of Set 13 | xacmaz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=namibe
# Processing Record 47 of Set 13 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kurilsk
# Processing Record 48 of Set 13 | kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tongliao
# Processing Record 49 of Set 13 | tongliao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=garissa
# Processing Record 50 of Set 13 | garissa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tilichiki
# Processing Record 1 of Set 14 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=serabu
# Processing Record 2 of Set 14 | serabu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tabiauea
# Processing Record 3 of Set 14 | tabiauea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=elizabeth+city
# Processing Record 4 of Set 14 | elizabeth city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=celestun
# Processing Record 5 of Set 14 | celestun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ormara
# Processing Record 6 of Set 14 | ormara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=grand+gaube
# Processing Record 7 of Set 14 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=choix
# Processing Record 8 of Set 14 | choix
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=gizo
# Processing Record 9 of Set 14 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bandarbeyla
# Processing Record 10 of Set 14 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=shimoda
# Processing Record 11 of Set 14 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=evensk
# Processing Record 12 of Set 14 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=morros
# Processing Record 13 of Set 14 | morros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=walla+walla
# Processing Record 14 of Set 14 | walla walla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mykolayiv
# Processing Record 15 of Set 14 | mykolayiv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=taitung
# Processing Record 16 of Set 14 | taitung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sunndalsora
# Processing Record 17 of Set 14 | sunndalsora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tynda
# Processing Record 18 of Set 14 | tynda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=palabuhanratu
# Processing Record 19 of Set 14 | palabuhanratu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=evansville
# Processing Record 20 of Set 14 | evansville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=morant+bay
# Processing Record 21 of Set 14 | morant bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tiarei
# Processing Record 22 of Set 14 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=galashiels
# Processing Record 23 of Set 14 | galashiels
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ballina
# Processing Record 24 of Set 14 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=san+miguel+de+cauri
# Processing Record 25 of Set 14 | san miguel de cauri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=san+patricio
# Processing Record 26 of Set 14 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kirakira
# Processing Record 27 of Set 14 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=yar-sale
# Processing Record 28 of Set 14 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tautira
# Processing Record 29 of Set 14 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lujiang
# Processing Record 30 of Set 14 | lujiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=richmond
# Processing Record 31 of Set 14 | richmond
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=poronaysk
# Processing Record 32 of Set 14 | poronaysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kamyaran
# Processing Record 33 of Set 14 | kamyaran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ambodifototra
# Processing Record 34 of Set 14 | ambodifototra
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=san+luis
# Processing Record 35 of Set 14 | san luis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=loa+janan
# Processing Record 36 of Set 14 | loa janan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hokitika
# Processing Record 37 of Set 14 | hokitika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=dicabisagan
# Processing Record 38 of Set 14 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=salekhard
# Processing Record 39 of Set 14 | salekhard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=utiroa
# Processing Record 40 of Set 14 | utiroa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=keokuk
# Processing Record 41 of Set 14 | keokuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=batticaloa
# Processing Record 42 of Set 14 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=rawson
# Processing Record 43 of Set 14 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sorland
# Processing Record 44 of Set 14 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=havoysund
# Processing Record 45 of Set 14 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=yumen
# Processing Record 46 of Set 14 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=taos
# Processing Record 47 of Set 14 | taos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kashi
# Processing Record 48 of Set 14 | kashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=lowestoft
# Processing Record 49 of Set 14 | lowestoft
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=weligama
# Processing Record 50 of Set 14 | weligama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=nakamura
# Processing Record 1 of Set 15 | nakamura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=miranorte
# Processing Record 2 of Set 15 | miranorte
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=rungata
# Processing Record 3 of Set 15 | rungata
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=moussoro
# Processing Record 4 of Set 15 | moussoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=utete
# Processing Record 5 of Set 15 | utete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=zhuhai
# Processing Record 6 of Set 15 | zhuhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mildura
# Processing Record 7 of Set 15 | mildura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tyret+pervaya
# Processing Record 8 of Set 15 | tyret pervaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ko+samui
# Processing Record 9 of Set 15 | ko samui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ulagan
# Processing Record 10 of Set 15 | ulagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tunghsiao
# Processing Record 11 of Set 15 | tunghsiao
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=san+ramon
# Processing Record 12 of Set 15 | san ramon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=zapolyarnyy
# Processing Record 13 of Set 15 | zapolyarnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=methoni
# Processing Record 14 of Set 15 | methoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=itarema
# Processing Record 15 of Set 15 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=chapais
# Processing Record 16 of Set 15 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=kapoeta
# Processing Record 17 of Set 15 | kapoeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=vulcan
# Processing Record 18 of Set 15 | vulcan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tigil
# Processing Record 19 of Set 15 | tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=linxia
# Processing Record 20 of Set 15 | linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=blue+springs
# Processing Record 21 of Set 15 | blue springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=erzincan
# Processing Record 22 of Set 15 | erzincan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=strzegom
# Processing Record 23 of Set 15 | strzegom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=markova
# Processing Record 24 of Set 15 | markova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=neiafu
# Processing Record 25 of Set 15 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=flin+flon
# Processing Record 26 of Set 15 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=despotovac
# Processing Record 27 of Set 15 | despotovac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=monchegorsk
# Processing Record 28 of Set 15 | monchegorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=wamba
# Processing Record 29 of Set 15 | wamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=tual
# Processing Record 30 of Set 15 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sistranda
# Processing Record 31 of Set 15 | sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=ciro+marina
# Processing Record 32 of Set 15 | ciro marina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=hovd
# Processing Record 33 of Set 15 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=bria
# Processing Record 34 of Set 15 | bria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=mitu
# Processing Record 35 of Set 15 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=acari
# Processing Record 36 of Set 15 | acari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=umarkot
# Processing Record 37 of Set 15 | umarkot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=half+moon+bay
# Processing Record 38 of Set 15 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=gasa
# Processing Record 39 of Set 15 | gasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=poso
# Processing Record 40 of Set 15 | poso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=progreso
# Processing Record 41 of Set 15 | progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=sal+rei
# Processing Record 42 of Set 15 | sal rei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da0286b3d86df84f307b63b7de035a39&q=alibunar
# Processing Record 43 of Set 15 | alibunar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.

city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Tasiilaq  65.6145  -37.6368     41.16        87          93
# 1  Vila Franca Do Campo  37.7167  -25.4333     74.19        88          40
# 2              Belmonte -15.8631  -38.8828     70.25        85          56
# 3               Nogliki  51.8333  143.1667     65.88        72          58
# 4               Mataura -46.1927  168.8643     45.48        86          80
#
#    Wind Speed Country   Current Weather
# 0        3.51      GL   overcast clouds
# 1        2.98      PT  scattered clouds
# 2        6.35      BR     broken clouds
# 3       11.34      RU     broken clouds
# 4        4.36      NZ     broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity","Cloudiness", "Wind Speed", "Current Weather"]
city_data_df= city_data_df[new_column_order ]
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Tasiilaq      GL  65.6145  -37.6368     41.16        87
# 1  Vila Franca Do Campo      PT  37.7167  -25.4333     74.19        88
# 2              Belmonte      BR -15.8631  -38.8828     70.25        85
# 3               Nogliki      RU  51.8333  143.1667     65.88        72
# 4               Mataura      NZ -46.1927  168.8643     45.48        86
# 5             Hithadhoo      MV  -0.6000   73.0833     81.90        72
# 6              Sisimiut      GL  66.9395  -53.6735     44.53        86
# 7            Bredasdorp      ZA -34.5322   20.0403     45.46        89
# 8                  Lata      PT  40.1629   -8.3327     55.80        89
# 9            Oranjemund      NA -28.5500   16.4333     61.75        32
#
#    Cloudiness  Wind Speed   Current Weather
# 0          93        3.51   overcast clouds
# 1          40        2.98  scattered clouds
# 2          56        6.35     broken clouds
# 3          58       11.34     broken clouds
# 4          80        4.36     broken clouds
# 5          75        7.99     broken clouds
# 6          72        4.92     broken clouds
# 7           0        5.95         clear sky
# 8           1        2.71         clear sky
# 9           0       12.64         clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
